# %%
from sandygrad.scalar import Scalar
from sandygrad.nn import *

# %%
# Train on the XOR problem
X = [[0, 0], [1, 0], [0, 1], [1, 1]]
y = [-1, 1, 1, -1]

# %%
model = MLP(2, [10, 1])
print(model)
# Out:
# MLP([Layer([Neuron(2), Neuron(2), Neuron(2), Neuron(2), Neuron(2), Neuron(2), Neuron(2), Neuron(2), Neuron(2), Neuron(2)]), Layer([Neuron(10)])])

# %%
lr = 0.1

for epoch in range(100):
    loss = []

    preds = []
    for Xi, yi in zip(X, y):
        #model.reset_dead_count()
        pred = model(Xi)
        preds.append(pred)
        #print(f"pred {pred}, ", end="")
        loss += [(1 - pred * yi).ReLU()]
    
    #print(model.zeros)

    total_loss = sum(loss)

    model.zero_grad()   
    total_loss.backward()

    for p in model.params():
        #print(f"{p.grad},", end="")
        p.data -= lr * p.grad

    print(f"epoch {epoch}, loss {total_loss.data}, {preds}", end="")

    print()
# Out:
# epoch 0, loss 4.878646826898697
# epoch 1, loss 4.202968800523086
# epoch 2, loss 3.9593180814247866
# epoch 3, loss 3.72660962515046
# epoch 4, loss 3.4994704013820095
# epoch 5, loss 3.293921286664278
# epoch 6, loss 3.0808675363171187
# epoch 7, loss 2.839028383674922
# epoch 8, loss 2.606623716847175
# epoch 9, loss 2.3059033611440056
# epoch 10, loss 2.0032994926110446
# epoch 11, loss 1.6446900131749125
# epoch 12, loss 1.6015051104738056
# epoch 13, loss 1.8403027738859064
# epoch 14, loss 1.6616416411832897
# epoch 15, loss 1.1645132604226034
# epoch 16, loss 0.910629361063417
# epoch 17, loss 0.8197548219678787
# epoch 18, loss 1.0434304168008728
# epoch 19, loss 1.2291778127326252
# epoch 20, loss 0.9019856106390327
# epoch 21, loss 1.1470002973768811
# epoch 22, loss 0.6
# epoch 23, loss 0.5
# epoch 24, loss 0.4
# epoch 25, loss 0.30000000000000004
# epoch 26, loss 0.34889970490097777
# epoch 27, loss 0.444571055420538
# epoch 28, loss 0.20000000000000007
# epoch 29, loss 0.10000000000000009
# epoch 30, loss 1.1102230246251565e-16
# epoch 31, loss 0.038506419069208375
# epoch 32, loss 0.03752853524153332
# epoch 33, loss 0.0
# epoch 34, loss 0.0
# epoch 35, loss 0.0
# epoch 36, loss 0.0
# epoch 37, loss 0.0
# epoch 38, loss 0.0
# epoch 39, loss 0.0
# epoch 40, loss 0.0
# epoch 41, loss 0.0
# epoch 42, loss 0.0
# epoch 43, loss 0.0
# epoch 44, loss 0.0
# epoch 45, loss 0.0
# epoch 46, loss 0.0
# epoch 47, loss 0.0
# epoch 48, loss 0.0
# epoch 49, loss 0.0
# epoch 50, loss 0.0
# epoch 51, loss 0.0
# epoch 52, loss 0.0
# epoch 53, loss 0.0
# epoch 54, loss 0.0
# epoch 55, loss 0.0
# epoch 56, loss 0.0
# epoch 57, loss 0.0
# epoch 58, loss 0.0
# epoch 59, loss 0.0
# epoch 60, loss 0.0
# epoch 61, loss 0.0
# epoch 62, loss 0.0
# epoch 63, loss 0.0
# epoch 64, loss 0.0
# epoch 65, loss 0.0
# epoch 66, loss 0.0
# epoch 67, loss 0.0
# epoch 68, loss 0.0
# epoch 69, loss 0.0
# epoch 70, loss 0.0
# epoch 71, loss 0.0
# epoch 72, loss 0.0
# epoch 73, loss 0.0
# epoch 74, loss 0.0
# epoch 75, loss 0.0
# epoch 76, loss 0.0
# epoch 77, loss 0.0
# epoch 78, loss 0.0
# epoch 79, loss 0.0
# epoch 80, loss 0.0
# epoch 81, loss 0.0
# epoch 82, loss 0.0
# epoch 83, loss 0.0
# epoch 84, loss 0.0
# epoch 85, loss 0.0
# epoch 86, loss 0.0
# epoch 87, loss 0.0
# epoch 88, loss 0.0
# epoch 89, loss 0.0
# epoch 90, loss 0.0
# epoch 91, loss 0.0
# epoch 92, loss 0.0
# epoch 93, loss 0.0
# epoch 94, loss 0.0
# epoch 95, loss 0.0
# epoch 96, loss 0.0
# epoch 97, loss 0.0
# epoch 98, loss 0.0
# epoch 99, loss 0.0
